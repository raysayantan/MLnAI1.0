# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
empdf = pd.read_csv(r"D:\Sayantan\Personal\MLnAI\InternalTraining\LVC\DataFiles\Empexport.csv", header=None)
empdf.columns = (["employee_id","first_name","last_name","job_id","salary","commission_pct","manager_id","department_id"])

# %%
empdf
# Out:
#      employee_id   first_name    last_name      job_id  salary commission_pct  \
# 0            100       Steven         King     AD_PRES   24000           Null
# 1            101        Neena      Kochhar       AD_VP   17000           Null
# 2            102          Lex      De Haan       AD_VP   17000           Null
# 3            103    Alexander       Hunold     IT_PROG    9000           Null
# 4            104        Bruce        Ernst     IT_PROG    6000           Null
# 5            105        David       Austin     IT_PROG    4800           Null
# 6            106        Valli    Pataballa     IT_PROG    4800           Null
# 7            107        Diana      Lorentz     IT_PROG    4200           Null
# 8            108        Nancy    Greenberg      FI_MGR   12008           Null
# 9            109       Daniel       Faviet  FI_ACCOUNT    9000           Null
# 10           110         John         Chen  FI_ACCOUNT    8200           Null
# ...

# %%
empdf.head()
# Out:
#    employee_id first_name last_name   job_id  salary commission_pct  \
# 0          101      Neena   Kochhar    AD_VP   17000           Null
# 1          102        Lex   De Haan    AD_VP   17000           Null
# 2          103  Alexander    Hunold  IT_PROG    9000           Null
# 3          104      Bruce     Ernst  IT_PROG    6000           Null
# 4          105      David    Austin  IT_PROG    4800           Null
#
#    manager_id department_id
# 0         100            90
# 1         100            90
# 2         102            60
# 3         103            60
# 4         103            60

# %%
empdf.head(10)
# Out:
#    employee_id first_name  last_name      job_id  salary commission_pct  \
# 0          101      Neena    Kochhar       AD_VP   17000           Null
# 1          102        Lex    De Haan       AD_VP   17000           Null
# 2          103  Alexander     Hunold     IT_PROG    9000           Null
# 3          104      Bruce      Ernst     IT_PROG    6000           Null
# 4          105      David     Austin     IT_PROG    4800           Null
# 5          106      Valli  Pataballa     IT_PROG    4800           Null
# 6          107      Diana    Lorentz     IT_PROG    4200           Null
# 7          108      Nancy  Greenberg      FI_MGR   12008           Null
# 8          109     Daniel     Faviet  FI_ACCOUNT    9000           Null
# 9          110       John       Chen  FI_ACCOUNT    8200           Null
#
#    manager_id department_id
# 0         100            90
# 1         100            90
# 2         102            60
# 3         103            60
# 4         103            60
# ...

# %%
empdf.tail(10)
# Out:
#      employee_id first_name  last_name      job_id  salary commission_pct  \
# 96           197      Kevin     Feeney    SH_CLERK    3000           Null
# 97           198     Donald   OConnell    SH_CLERK    2600           Null
# 98           199    Douglas      Grant    SH_CLERK    2600           Null
# 99           200   Jennifer     Whalen     AD_ASST    4400           Null
# 100          201    Michael  Hartstein      MK_MAN   13000           Null
# 101          202        Pat        Fay      MK_REP    6000           Null
# 102          203      Susan     Mavris      HR_REP    6500           Null
# 103          204    Hermann       Baer      PR_REP   10000           Null
# 104          205    Shelley    Higgins      AC_MGR   12008           Null
# 105          206    William      Gietz  AC_ACCOUNT    8300           Null
#
#      manager_id department_id
# 96          124            50
# 97          124            50
# 98          124            50
# ...

# %%
empdf.columns
# Out:
# Index(['employee_id', 'first_name', 'last_name', 'job_id', 'salary',
#        'commission_pct', 'manager_id', 'department_id'],
#       dtype='object')

# %%
len(empdf.columns)
# Out:
# 8

# %%
len(empdf)
# Out:
# 106

# %%
empdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 8 columns):
# employee_id       107 non-null int64
# first_name        107 non-null object
# last_name         107 non-null object
# job_id            107 non-null object
# salary            107 non-null int64
# commission_pct    107 non-null object
# manager_id        107 non-null object
# department_id     107 non-null object
# dtypes: int64(2), object(6)
# memory usage: 6.8+ KB

# %%
empdf.describe()
# Out:
#        employee_id        salary
# count   107.000000    107.000000
# mean    153.000000   6461.831776
# std      31.032241   3909.579731
# min     100.000000   2100.000000
# 25%     126.500000   3100.000000
# 50%     153.000000   6200.000000
# 75%     179.500000   8900.000000
# max     206.000000  24000.000000

# %%
#slicing
empdf[:]
# Out:
#      employee_id   first_name    last_name      job_id  salary commission_pct  \
# 0            100       Steven         King     AD_PRES   24000           Null
# 1            101        Neena      Kochhar       AD_VP   17000           Null
# 2            102          Lex      De Haan       AD_VP   17000           Null
# 3            103    Alexander       Hunold     IT_PROG    9000           Null
# 4            104        Bruce        Ernst     IT_PROG    6000           Null
# 5            105        David       Austin     IT_PROG    4800           Null
# 6            106        Valli    Pataballa     IT_PROG    4800           Null
# 7            107        Diana      Lorentz     IT_PROG    4200           Null
# 8            108        Nancy    Greenberg      FI_MGR   12008           Null
# 9            109       Daniel       Faviet  FI_ACCOUNT    9000           Null
# 10           110         John         Chen  FI_ACCOUNT    8200           Null
# ...

# %%
empdf[10:100:10]
# Out:
#     employee_id first_name last_name      job_id  salary commission_pct  \
# 10          110       John      Chen  FI_ACCOUNT    8200           Null
# 20          120    Matthew     Weiss      ST_MAN    8000           Null
# 30          130      Mozhe  Atkinson    ST_CLERK    2800           Null
# 40          140     Joshua     Patel    ST_CLERK    2500           Null
# 50          150      Peter    Tucker      SA_REP   10000            0.3
# 60          160     Louise     Doran      SA_REP    7500            0.3
# 70          170     Tayler       Fox      SA_REP    9600            0.2
# 80          180    Winston    Taylor    SH_CLERK    3200           Null
# 90          190    Timothy     Gates    SH_CLERK    2900           Null
#
#    manager_id department_id
# 10        108           100
# 20        100            50
# 30        121            50
# 40        123            50
# 50        145            80
# 60        146            80
# 70        148            80
# ...

# %%
empdf[::-1]
# Out:
#      employee_id   first_name    last_name      job_id  salary commission_pct  \
# 106          206      William        Gietz  AC_ACCOUNT    8300           Null
# 105          205      Shelley      Higgins      AC_MGR   12008           Null
# 104          204      Hermann         Baer      PR_REP   10000           Null
# 103          203        Susan       Mavris      HR_REP    6500           Null
# 102          202          Pat          Fay      MK_REP    6000           Null
# 101          201      Michael    Hartstein      MK_MAN   13000           Null
# 100          200     Jennifer       Whalen     AD_ASST    4400           Null
# 99           199      Douglas        Grant    SH_CLERK    2600           Null
# 98           198       Donald     OConnell    SH_CLERK    2600           Null
# 97           197        Kevin       Feeney    SH_CLERK    3000           Null
# 96           196        Alana        Walsh    SH_CLERK    3100           Null
# ...

# %%
empdf[10:100:10][["employee_id","last_name","salary"]]
# Out:
#     employee_id last_name  salary
# 10          110      Chen    8200
# 20          120     Weiss    8000
# 30          130  Atkinson    2800
# 40          140     Patel    2500
# 50          150    Tucker   10000
# 60          160     Doran    7500
# 70          170       Fox    9600
# 80          180    Taylor    3200
# 90          190     Gates    2900

# %%
empdf.head(10)[["employee_id","last_name","salary"]]
# Out:
#    employee_id  last_name  salary
# 0          100       King   24000
# 1          101    Kochhar   17000
# 2          102    De Haan   17000
# 3          103     Hunold    9000
# 4          104      Ernst    6000
# 5          105     Austin    4800
# 6          106  Pataballa    4800
# 7          107    Lorentz    4200
# 8          108  Greenberg   12008
# 9          109     Faviet    9000

# %%
empdf.describe()[["salary"]]
# Out:
#              salary
# count    107.000000
# mean    6461.831776
# std     3909.579731
# min     2100.000000
# 25%     3100.000000
# 50%     6200.000000
# 75%     8900.000000
# max    24000.000000

# %%
empdf[empdf.salary > 10000][["employee_id","last_name","salary"]]
# Out:
#      employee_id  last_name  salary
# 0            100       King   24000
# 1            101    Kochhar   17000
# 2            102    De Haan   17000
# 8            108  Greenberg   12008
# 14           114   Raphaely   11000
# 45           145    Russell   14000
# 46           146   Partners   13500
# 47           147  Errazuriz   12000
# 48           148  Cambrault   11000
# 49           149    Zlotkey   10500
# 62           162    Vishney   10500
# 68           168       Ozer   11500
# 74           174       Abel   11000
# 101          201  Hartstein   13000
# 105          205    Higgins   12008

# %%
empdf[empdf["salary"] > 10000][["employee_id","last_name","salary"]]#if column name have space then have to use this syntax
# Out:
#      employee_id  last_name  salary
# 0            100       King   24000
# 1            101    Kochhar   17000
# 2            102    De Haan   17000
# 8            108  Greenberg   12008
# 14           114   Raphaely   11000
# 45           145    Russell   14000
# 46           146   Partners   13500
# 47           147  Errazuriz   12000
# 48           148  Cambrault   11000
# 49           149    Zlotkey   10500
# 62           162    Vishney   10500
# 68           168       Ozer   11500
# 74           174       Abel   11000
# 101          201  Hartstein   13000
# 105          205    Higgins   12008

# %%
empdf[(empdf.salary < 5000) & (empdf.department_id == '50')][["employee_id","last_name","salary","department_id"]]
# Out:
#     employee_id    last_name  salary department_id
# 25          125        Nayer    3200            50
# 26          126  Mikkilineni    2700            50
# 27          127       Landry    2400            50
# 28          128       Markle    2200            50
# 29          129       Bissot    3300            50
# 30          130     Atkinson    2800            50
# 31          131       Marlow    2500            50
# 32          132        Olson    2100            50
# 33          133       Mallin    3300            50
# 34          134       Rogers    2900            50
# 35          135          Gee    2400            50
# 36          136   Philtanker    2200            50
# 37          137       Ladwig    3600            50
# 38          138       Stiles    3200            50
# 39          139          Seo    2700            50
# 40          140        Patel    2500            50
# 41          141         Rajs    3500            50
# ...

# %%
empdf[(empdf.job_id == 'MK_MAN') | (empdf.department_id == '90')][["employee_id","last_name","job_id","department_id"]]
# Out:
#      employee_id  last_name   job_id department_id
# 0            100       King  AD_PRES            90
# 1            101    Kochhar    AD_VP            90
# 2            102    De Haan    AD_VP            90
# 101          201  Hartstein   MK_MAN            20

# %%
empdf[empdf.job_id.isin(["SA_REP", "MK_MAN" ,"PU_CLERK", "ST_CLERK"])][["employee_id","last_name","job_id","department_id"]]
# Out:
#      employee_id    last_name    job_id department_id
# 15           115         Khoo  PU_CLERK            30
# 16           116        Baida  PU_CLERK            30
# 17           117       Tobias  PU_CLERK            30
# 18           118       Himuro  PU_CLERK            30
# 19           119   Colmenares  PU_CLERK            30
# 25           125        Nayer  ST_CLERK            50
# 26           126  Mikkilineni  ST_CLERK            50
# 27           127       Landry  ST_CLERK            50
# 28           128       Markle  ST_CLERK            50
# 29           129       Bissot  ST_CLERK            50
# 30           130     Atkinson  ST_CLERK            50
# 31           131       Marlow  ST_CLERK            50
# 32           132        Olson  ST_CLERK            50
# 33           133       Mallin  ST_CLERK            50
# 34           134       Rogers  ST_CLERK            50
# 35           135          Gee  ST_CLERK            50
# ...

# %%
empdf[empdf.job_id.str.contains('CLERK')][["job_id"]]
# Out:
#       job_id
# 15  PU_CLERK
# 16  PU_CLERK
# 17  PU_CLERK
# 18  PU_CLERK
# 19  PU_CLERK
# 25  ST_CLERK
# 26  ST_CLERK
# 27  ST_CLERK
# 28  ST_CLERK
# 29  ST_CLERK
# 30  ST_CLERK
# 31  ST_CLERK
# 32  ST_CLERK
# 33  ST_CLERK
# 34  ST_CLERK
# 35  ST_CLERK
# 36  ST_CLERK
# 37  ST_CLERK
# 38  ST_CLERK
# 39  ST_CLERK
# 40  ST_CLERK
# 41  ST_CLERK
# 42  ST_CLERK
# 43  ST_CLERK
# 44  ST_CLERK
# 80  SH_CLERK
# 81  SH_CLERK
# 82  SH_CLERK
# 83  SH_CLERK
# 84  SH_CLERK
# 85  SH_CLERK
# 86  SH_CLERK
# 87  SH_CLERK
# 88  SH_CLERK
# 89  SH_CLERK
# 90  SH_CLERK
# 91  SH_CLERK
# 92  SH_CLERK
# 93  SH_CLERK
# 94  SH_CLERK
# 95  SH_CLERK
# 96  SH_CLERK
# 97  SH_CLERK
# 98  SH_CLERK
# 99  SH_CLERK

# %%
empdf[empdf.last_name.str.startswith('A')][["last_name"]]
# Out:
#    last_name
# 5     Austin
# 30  Atkinson
# 66      Ande
# 74      Abel

# %%
empdf.sort_values(by="salary", ascending=False)[["employee_id","last_name","salary"]]
# Out:
#      employee_id    last_name  salary
# 0            100         King   24000
# 2            102      De Haan   17000
# 1            101      Kochhar   17000
# 45           145      Russell   14000
# 46           146     Partners   13500
# 101          201    Hartstein   13000
# 8            108    Greenberg   12008
# 105          205      Higgins   12008
# 47           147    Errazuriz   12000
# 68           168         Ozer   11500
# 48           148    Cambrault   11000
# 74           174         Abel   11000
# 14           114     Raphaely   11000
# 62           162      Vishney   10500
# 49           149      Zlotkey   10500
# 104          204         Baer   10000
# 50           150       Tucker   10000
# 56           156         King   10000
# 69           169        Bloom   10000
# 70           170          Fox    9600
# 57           157        Sully    9500
# 51           151    Bernstein    9500
# 63           163       Greene    9500
# 58           158       McEwen    9000
# ...

# %%
#Group BY
gResult = empdf.groupby("department_id")["salary"].sum()
gResult.plot.bar()
plt.show()

# %%
gResult = empdf.groupby("job_id")["employee_id"].count()
gResult.plot.bar()
plt.show()

# %%
gResult = empdf.groupby("manager_id")["salary"].max()
gResult.plot.bar()
plt.show()

# %%
gResult = empdf.groupby(["department_id","job_id"])["salary"].sum()
gResult.plot.bar()
plt.show()

# %%
empdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 8 columns):
# employee_id       107 non-null int64
# first_name        107 non-null object
# last_name         107 non-null object
# job_id            107 non-null object
# salary            107 non-null int64
# commission_pct    107 non-null object
# manager_id        107 non-null object
# department_id     107 non-null object
# dtypes: int64(2), object(6)
# memory usage: 6.8+ KB

# %%
#Lamda
empdf.department_id = empdf.department_id.apply(lambda x : 0 if x == 'Null' else int(x))

# %%
empdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 8 columns):
# employee_id       107 non-null int64
# first_name        107 non-null object
# last_name         107 non-null object
# job_id            107 non-null object
# salary            107 non-null int64
# commission_pct    107 non-null object
# manager_id        107 non-null object
# department_id     107 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 6.8+ KB

# %%
empdf.manager_id = empdf.manager_id.apply(lambda x : 0 if x == 'Null' else x)

# %%
empdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 8 columns):
# employee_id       107 non-null int64
# first_name        107 non-null object
# last_name         107 non-null object
# job_id            107 non-null object
# salary            107 non-null int64
# commission_pct    107 non-null object
# manager_id        107 non-null int64
# department_id     107 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 6.8+ KB

# %%
empdf.manager_id = empdf.manager_id.astype("int64")
empdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 8 columns):
# employee_id       107 non-null int64
# first_name        107 non-null object
# last_name         107 non-null object
# job_id            107 non-null object
# salary            107 non-null int64
# commission_pct    107 non-null object
# manager_id        107 non-null int64
# department_id     107 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 6.8+ KB

# %%
#complex function we can define our own function
def comm(x):
    if x == 'Null':
        return 0.0
    else:
        return float(x)
    
empdf.commission_pct = empdf.commission_pct.apply(comm)

# %%
empdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 8 columns):
# employee_id       107 non-null int64
# first_name        107 non-null object
# last_name         107 non-null object
# job_id            107 non-null object
# salary            107 non-null int64
# commission_pct    107 non-null float64
# manager_id        107 non-null int64
# department_id     107 non-null int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 6.8+ KB

# %%
empdfCp = empdf[10:20][["employee_id","last_name","salary"]].copy()

# %%
empdfCp
# Out:
#     employee_id   last_name  salary
# 10          110        Chen    8200
# 11          111     Sciarra    7700
# 12          112       Urman    7800
# 13          113        Popp    6900
# 14          114    Raphaely   11000
# 15          115        Khoo    3100
# 16          116       Baida    2900
# 17          117      Tobias    2800
# 18          118      Himuro    2600
# 19          119  Colmenares    2500

# %%
#add new column annual salary to df
empdfCp["annual_sal"] = empdfCp.salary*12

# %%
empdfCp.head()
# Out:
#     employee_id last_name  salary
# 10          110      Chen    8200
# 11          111   Sciarra    7700
# 12          112     Urman    7800
# 13          113      Popp    6900
# 14          114  Raphaely   11000

# %%
empdfCp.drop("annual_sal", axis=1,inplace=True)

# %%
empdfCp
# Out:
#     employee_id   last_name  salary
# 10          110        Chen    8200
# 11          111     Sciarra    7700
# 12          112       Urman    7800
# 13          113        Popp    6900
# 14          114    Raphaely   11000
# 15          115        Khoo    3100
# 16          116       Baida    2900
# 17          117      Tobias    2800
# 18          118      Himuro    2600
# 19          119  Colmenares    2500

# %%
empdfCp.drop([13,17],inplace=True)

# %%
empdfCp
# Out:
#     employee_id   last_name  salary
# 10          110        Chen    8200
# 11          111     Sciarra    7700
# 12          112       Urman    7800
# 14          114    Raphaely   11000
# 15          115        Khoo    3100
# 16          116       Baida    2900
# 18          118      Himuro    2600
# 19          119  Colmenares    2500

# %%
empdfCp[empdfCp.salary < 3000].index
# Out:
# Int64Index([16, 18, 19], dtype='int64')

# %%
empdfCp.drop(empdfCp[empdfCp.salary < 3000].index,inplace=True)

# %%
empdfCp
# Out:
#     employee_id last_name  salary
# 10          110      Chen    8200
# 11          111   Sciarra    7700
# 12          112     Urman    7800
# 14          114  Raphaely   11000
# 15          115      Khoo    3100

# %%
empdfCp.at[12,"last_name"]="Oracle"

# %%
empdfCp
# Out:
#     employee_id last_name  salary
# 10          110      Chen    8200
# 11          111   Sciarra    7700
# 12          112    Oracle    7800
# 14          114  Raphaely   11000
# 15          115      Khoo    3100

# %%
empdfCp.iat[4,1]="Oracle USA"

# %%
empdfCp
# Out:
#     employee_id   last_name  salary
# 10          110        Chen    8200
# 11          111     Sciarra    7700
# 12          112      Oracle    7800
# 14          114    Raphaely   11000
# 15          115  Oracle USA    3100

# %%
empdf.iloc[0:10,0:5]
# Out:
#    employee_id first_name  last_name      job_id  salary
# 0          100     Steven       King     AD_PRES   24000
# 1          101      Neena    Kochhar       AD_VP   17000
# 2          102        Lex    De Haan       AD_VP   17000
# 3          103  Alexander     Hunold     IT_PROG    9000
# 4          104      Bruce      Ernst     IT_PROG    6000
# 5          105      David     Austin     IT_PROG    4800
# 6          106      Valli  Pataballa     IT_PROG    4800
# 7          107      Diana    Lorentz     IT_PROG    4200
# 8          108      Nancy  Greenberg      FI_MGR   12008
# 9          109     Daniel     Faviet  FI_ACCOUNT    9000

# %%
empdf.iloc[0:10,[2]]
# Out:
#    last_name
# 0       King
# 1    Kochhar
# 2    De Haan
# 3     Hunold
# 4      Ernst
# 5     Austin
# 6  Pataballa
# 7    Lorentz
# 8  Greenberg
# 9     Faviet

# %%
empdf.iloc[0:10,[2,5,7]]
# Out:
#    last_name  commission_pct  department_id
# 0       King             0.0             90
# 1    Kochhar             0.0             90
# 2    De Haan             0.0             90
# 3     Hunold             0.0             60
# 4      Ernst             0.0             60
# 5     Austin             0.0             60
# 6  Pataballa             0.0             60
# 7    Lorentz             0.0             60
# 8  Greenberg             0.0            100
# 9     Faviet             0.0            100

# %%
empdf.iloc[:,:]
# Out:
#      employee_id   first_name    last_name      job_id  salary  \
# 0            100       Steven         King     AD_PRES   24000
# 1            101        Neena      Kochhar       AD_VP   17000
# 2            102          Lex      De Haan       AD_VP   17000
# 3            103    Alexander       Hunold     IT_PROG    9000
# 4            104        Bruce        Ernst     IT_PROG    6000
# 5            105        David       Austin     IT_PROG    4800
# 6            106        Valli    Pataballa     IT_PROG    4800
# 7            107        Diana      Lorentz     IT_PROG    4200
# 8            108        Nancy    Greenberg      FI_MGR   12008
# 9            109       Daniel       Faviet  FI_ACCOUNT    9000
# 10           110         John         Chen  FI_ACCOUNT    8200
# 11           111       Ismael      Sciarra  FI_ACCOUNT    7700
# 12           112  Jose Manuel        Urman  FI_ACCOUNT    7800
# 13           113         Luis         Popp  FI_ACCOUNT    6900
# ...

# %%
empdf.iloc[:,:-1]
# Out:
#      employee_id   first_name    last_name      job_id  salary  \
# 0            100       Steven         King     AD_PRES   24000
# 1            101        Neena      Kochhar       AD_VP   17000
# 2            102          Lex      De Haan       AD_VP   17000
# 3            103    Alexander       Hunold     IT_PROG    9000
# 4            104        Bruce        Ernst     IT_PROG    6000
# 5            105        David       Austin     IT_PROG    4800
# 6            106        Valli    Pataballa     IT_PROG    4800
# 7            107        Diana      Lorentz     IT_PROG    4200
# 8            108        Nancy    Greenberg      FI_MGR   12008
# 9            109       Daniel       Faviet  FI_ACCOUNT    9000
# 10           110         John         Chen  FI_ACCOUNT    8200
# 11           111       Ismael      Sciarra  FI_ACCOUNT    7700
# 12           112  Jose Manuel        Urman  FI_ACCOUNT    7800
# 13           113         Luis         Popp  FI_ACCOUNT    6900
# ...

# %%
yArray = empdf.iloc[0:10,4].values

# %%
print(type(yArray))
print(yArray.ndim)
print(yArray.shape)
print(yArray)
# Out:
# <class 'numpy.ndarray'>
# 1
# (10,)
# [24000 17000 17000  9000  6000  4800  4800  4200 12008  9000]

# %%
empdf.to_csv(r"D:\Sayantan\Personal\MLnAI\InternalTraining\LVC\DataFiles\outPut.csv",sep=',',mode='a',index=None)

# %%
InputDataDictn1 = {
        'course_id': ['901', '902', '903', '904', '905'],
        'first_name': ['Steven', 'Alex', 'Lee', 'John', 'Greg'], 
        'last_name': ['King', 'Maden', 'Chan', 'Bruce', 'Wargus']}
DFstu1 = pd.DataFrame(InputDataDictn1 ,
		columns = ['course_id', 'first_name', 'last_name'])
DFstu1 
#---------------------------
InputDataDictn2 = {
        'course_id': ['904', '905', '906', '907', '908'],
        'first_name': ['Tina', 'Trecy', 'Andria', 'Eliza', 'Gracy'], 
        'last_name': ['Smith', 'Muller', 'Morgan', 'Johnson', 'Jordan']}

DFstu2 = pd.DataFrame(InputDataDictn2 ,columns = ['course_id', 'first_name', 'last_name'])

DFstu2

#---------------------------
InputDataDict3 = {
        'course_id': ['901', '902', '903', '904', '905', '907', '908', '909', '910', '911'],
        'exam_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}
DFtest = pd.DataFrame(InputDataDict3, columns = ['course_id','exam_id'])
DFtest
#-----------------Join the two dataframes along rows------------------------

DFstudent  = pd.concat([DFstu1 , DFstu2 ])
DFstudent
# Out:
#   course_id first_name last_name
# 0       901     Steven      King
# 1       902       Alex     Maden
# 2       903        Lee      Chan
# 3       904       John     Bruce
# 4       905       Greg    Wargus
# 0       904       Tina     Smith
# 1       905      Trecy    Muller
# 2       906     Andria    Morgan
# 3       907      Eliza   Johnson
# 4       908      Gracy    Jordan

# %%
pd.concat([DFstu1 , DFstu2 ],axis=1)
# Out:
#   course_id first_name last_name course_id first_name last_name
# 0       901     Steven      King       904       Tina     Smith
# 1       902       Alex     Maden       905      Trecy    Muller
# 2       903        Lee      Chan       906     Andria    Morgan
# 3       904       John     Bruce       907      Eliza   Johnson
# 4       905       Greg    Wargus       908      Gracy    Jordan

# %%
#------------Merge two dataframes along the course_id value-----------------

pd.merge(DFstudent  , DFtest , on='course_id')
# Out:
#   course_id first_name last_name  exam_id
# 0       901     Steven      King       51
# 1       902       Alex     Maden       15
# 2       903        Lee      Chan       15
# 3       904       John     Bruce       61
# 4       904       Tina     Smith       61
# 5       905       Greg    Wargus       16
# 6       905      Trecy    Muller       16
# 7       907      Eliza   Johnson       14
# 8       908      Gracy    Jordan       15

# %%
pd.merge(DFstu1 , DFstu2, on='course_id', how='inner', suffixes=('_DFstu1','_DFstu2'))
# Out:
#   course_id first_name_DFstu1 last_name_DFstu1 first_name_DFstu2  \
# 0       904              John            Bruce              Tina
# 1       905              Greg           Wargus             Trecy
#
#   last_name_DFstu2
# 0            Smith
# 1           Muller
